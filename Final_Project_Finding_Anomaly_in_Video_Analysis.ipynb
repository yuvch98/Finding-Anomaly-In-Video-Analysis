# %% [markdown]
# <a href="https://colab.research.google.com/github/yuvch98/Finding-Anomaly-In-Video-Analysis/blob/main/Final_Project_Finding_Anomaly_in_Video_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing files and libraries
import cv2
import numpy as np
from google.colab.patches import cv2_imshow
from matplotlib import pyplot as plt

#frame - has 240x320 pixels
#pixel - (0-255,0-255,0-255)
#we receive the frame already in a shape of (240,320,3)
#we need to flatten it in order to put it in a model
#
cap = cv2.VideoCapture("Abuse001_x264.mp4")
while True:

    ret, frame =cap.read()
    print(len(frame))
    plt.imshow(frame, cmap='gray')
    plt.show()
    break

cap.release()
cv2.destroyAllWindows()

label = [0, 1] # normal / anomaly
# Out:
# 240
